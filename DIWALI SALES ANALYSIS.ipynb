# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('DIWALI SALES ANALYSIS.csv', encoding= 'unicode_escape')

# %%
#deduce count of column and rows
df.shape
# Out:
# (11251, 13)

# %%
#deduce all column and rows
df.head(5)
# Out:
#    User_ID Cust_name Gender Age Group  Age  Marital_Status           State  \
# 0  1000001     Aaron      F      0-17   12               0  AndhraÿPradesh
# 1  1000002     Aaron      F      0-17   12               0  AndhraÿPradesh
# 2  1000003     Aaron      F      0-17   12               0  AndhraÿPradesh
# 3  1000003     Aaron      F      0-17   12               0  AndhraÿPradesh
# 4  1000004     Aaron      F      0-17   12               0  AndhraÿPradesh
#
#       Zone   Occupation Product_ID Product_Category  Orders  Amount
# 0  Central  Agriculture  P00000142             Auto       1   188.0
# 1  Central  Agriculture  P00000142             Auto       1   206.0
# 2  Central  Agriculture  P00000142             Auto       1   213.0
# 3  Central  Agriculture  P00000142             Auto       1   367.0
# 4  Central  Agriculture  P00000142             Auto       1   370.0

# %%
#deduce all count of column Non-Null Count  Dtype 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Gender            11251 non-null  object
#  3   Age Group         11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_ID        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#check for null values (identified values,avoid errors)
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_ID           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#deduce status
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Gender  Age Group    Age  Marital_Status  State  \
# 0        False      False   False      False  False           False  False
# 1        False      False   False      False  False           False  False
# 2        False      False   False      False  False           False  False
# 3        False      False   False      False  False           False  False
# 4        False      False   False      False  False           False  False
# ...        ...        ...     ...        ...    ...             ...    ...
# 11246    False      False   False      False  False           False  False
# 11247    False      False   False      False  False           False  False
# 11248    False      False   False      False  False           False  False
# 11249    False      False   False      False  False           False  False
# 11250    False      False   False      False  False           False  False
#
# ...

# %%
#deduce all coumn and rows
df.shape
# Out:
# (11251, 13)

# %%
# drop null values
df.dropna(inplace=True)

# %%
# change data type conversion
df['Amount'] = df['Amount'].astype('int')

# %%
#check
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Gender', 'Age Group', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_ID', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Marital_Status':'Marriage'})
# Out:
#        User_ID Cust_name Gender Age Group  Age  Marriage           State  \
# 0      1000001     Aaron      F      0-17   12         0  AndhraÿPradesh
# 1      1000002     Aaron      F      0-17   12         0  AndhraÿPradesh
# 2      1000003     Aaron      F      0-17   12         0  AndhraÿPradesh
# 3      1000003     Aaron      F      0-17   12         0  AndhraÿPradesh
# 4      1000004     Aaron      F      0-17   12         0  AndhraÿPradesh
# ...        ...       ...    ...       ...  ...       ...             ...
# 11234  1006036     Zydlo      M       55+   90         1     Uttarakhand
# 11235  1006036     Zydlo      M       55+   91         1     Uttarakhand
# 11236  1006036     Zydlo      M       55+   91         1     Uttarakhand
# 11237  1006036     Zydlo      M       55+   91         1     Uttarakhand
# 11238  1006036     Zydlo      M       55+   91         1     Uttarakhand
#
#           Zone   Occupation Product_ID Product_Category  Orders  Amount
# ...

# %%
#rename column
df.rename(columns= {'Cust_name':'CUSTOMER NAME'})
# Out:
#        User_ID CUSTOMER NAME Gender Age Group  Age  Marital_Status  \
# 0      1000001         Aaron      F      0-17   12               0
# 1      1000002         Aaron      F      0-17   12               0
# 2      1000003         Aaron      F      0-17   12               0
# 3      1000003         Aaron      F      0-17   12               0
# 4      1000004         Aaron      F      0-17   12               0
# ...        ...           ...    ...       ...  ...             ...
# 11234  1006036         Zydlo      M       55+   90               1
# 11235  1006036         Zydlo      M       55+   91               1
# 11236  1006036         Zydlo      M       55+   91               1
# 11237  1006036         Zydlo      M       55+   91               1
# 11238  1006036         Zydlo      M       55+   91               1
#
#                 State     Zone   Occupation Product_ID Product_Category  \
# 0      AndhraÿPradesh  Central  Agriculture  P00000142             Auto
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc) 0 to 100 everything

df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003001e+06     35.361242        0.419699      2.487677   9453.610553
# std    1.714174e+03     12.628120        0.493532      1.114548   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001491e+06     27.000000        0.000000      1.000000   5443.000000
# 50%    1.003062e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004425e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006036e+06     91.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.361242      2.487677   9453.610553
# std       12.628120      1.114548   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       91.000000      4.000000  23952.000000

# %%
print('Exploratory Data Analysis')
# Out:
# Exploratory Data Analysis

# %%
#1.Gender

df.columns

# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#clear data
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender    Amount
# 1      M  54878575
# 0      F  51370554

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(y = 'Gender',x = 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Amount', ylabel='Gender'>

# %%
#2.AGE

#clear data
df.groupby(['Age'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#     Age   Amount
# 23   35  4069735
# 22   34  3781221
# 18   30  3713752
# 33   45  3697062
# 38   50  3563991
# ..  ...      ...
# 5    17    74350
# 3    15    62702
# 1    13    40139
# 2    14    28372
# 0    12    27943
#
# [80 rows x 2 columns]

# %%
#graph
ax = sns.countplot(data = df, y = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# clear graph Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
#3.STATE

#  graph total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# clear graph total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(15)
sns.set(rc={'figure.figsize':(30,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
#4.MARRIAGE

# graph
ax = sns.countplot(data = df, x = 'Marital_Status')
sns.set(rc={'figure.figsize':(15,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# clear graph
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
#5. OCCUPATION

# graph
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# clear graph
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
#6. PRODUCT CATEGORY

# graph
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# clear graph
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
# clear graph
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# clear graph top 10 most sold products (same thing as above)
fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
#Conclusion 
#Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT,Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
